# %%
import requests 
import json
import os 
# !pip install python-dotenv
from dotenv import load_dotenv
import pandas as pd
from bs4 import BeautifulSoup

# %%
doc = open('output.json')
data = json.load(doc)
data
# Out:
# {'login': 'Katiahsotelo',
#  'id': 104922109,
#  'node_id': 'U_kgDOBkD7_Q',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/104922109?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Katiahsotelo',
#  'html_url': 'https://github.com/Katiahsotelo',
#  'followers_url': 'https://api.github.com/users/Katiahsotelo/followers',
#  'following_url': 'https://api.github.com/users/Katiahsotelo/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Katiahsotelo/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Katiahsotelo/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Katiahsotelo/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Katiahsotelo/orgs',
#  'repos_url': 'https://api.github.com/users/Katiahsotelo/repos',
#  'events_url': 'https://api.github.com/users/Katiahsotelo/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Katiahsotelo/received_events',
# ...

# %% [markdown]
# Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# Obtain the full list of forks created from the main lab repo via Github API.
#
# Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like:

# %%
token= "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"
username='Katiahsotelo'

# %%
dat = open('output2.json')
data = json.load(dat)
data
# Out:
# [{'id': 528225470,
#   'node_id': 'R_kgDOH3wUvg',
#   'name': 'lab-API_SCAVANGER',
#   'full_name': 'enrunz/lab-API_SCAVANGER',
#   'private': False,
#   'owner': {'login': 'enrunz',
#    'id': 105838147,
#    'node_id': 'U_kgDOBk72Qw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105838147?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enrunz',
#    'html_url': 'https://github.com/enrunz',
#    'followers_url': 'https://api.github.com/users/enrunz/followers',
#    'following_url': 'https://api.github.com/users/enrunz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/enrunz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/enrunz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/enrunz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/enrunz/orgs',
#    'repos_url': 'https://api.github.com/users/enrunz/repos',
# ...

# %%
jason = []
for i in range(0,5):
    url=f'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/forks?page={i}'
    page=requests.get(url, auth=(username,token))
    page1 = page.json()
    jason.append(page1)

# %%
jason
# Out:
# [[{'id': 528225470,
#    'node_id': 'R_kgDOH3wUvg',
#    'name': 'lab-API_SCAVANGER',
#    'full_name': 'enrunz/lab-API_SCAVANGER',
#    'private': False,
#    'owner': {'login': 'enrunz',
#     'id': 105838147,
#     'node_id': 'U_kgDOBk72Qw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/105838147?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/enrunz',
#     'html_url': 'https://github.com/enrunz',
#     'followers_url': 'https://api.github.com/users/enrunz/followers',
#     'following_url': 'https://api.github.com/users/enrunz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/enrunz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/enrunz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/enrunz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/enrunz/orgs',
#     'repos_url': 'https://api.github.com/users/enrunz/repos',
# ...

# %%
##########Lenguajes
lang = []
for i in jason:
    for j in i:
        for key,value in j.items():
            if key == 'language':
                lang.append(value)

# %%
list(set(lang))
# Out:
# ['Jupyter Notebook', None, 'Python']

# %% [markdown]
# Challenge 2: Count Commits
#
# Count how many commits were made in the past week.
#
# Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %%
url=f'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/commits'
page=requests.get(url, auth=(username,token))
commits_json = page.json()

# %%
commits_json
# Out:
# [{'sha': 'ac6d42854434acfafe92b60fdf2ed0b038de2070',
#   'node_id': 'MDY6Q29tbWl0NDAyMTUwMjYxOmFjNmQ0Mjg1NDQzNGFjZmFmZTkyYjYwZmRmMmVkMGIwMzhkZTIwNzA=',
#   'commit': {'author': {'name': 'daniloxxv',
#     'email': 'danilosoares@gmail.com',
#     'date': '2019-06-25T17:26:30Z'},
#    'committer': {'name': 'daniloxxv',
#     'email': 'danilosoares@gmail.com',
#     'date': '2019-06-25T17:26:30Z'},
#    'message': 'Uploading module 1 labs',
#    'tree': {'sha': '630fb3256855111b1e78d609c4ce1964a9fdb47a',
#     'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/trees/630fb3256855111b1e78d609c4ce1964a9fdb47a'},
#    'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/commits/ac6d42854434acfafe92b60fdf2ed0b038de2070',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
com = {}
for i in commits_json:
    for key,value in i.items():
        if key == 'commit':
            com[key] = value
            print(key,value)
# Out:
# commit {'author': {'name': 'daniloxxv', 'email': 'danilosoares@gmail.com', 'date': '2019-06-25T17:26:30Z'}, 'committer': {'name': 'daniloxxv', 'email': 'danilosoares@gmail.com', 'date': '2019-06-25T17:26:30Z'}, 'message': 'Uploading module 1 labs', 'tree': {'sha': '630fb3256855111b1e78d609c4ce1964a9fdb47a', 'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/trees/630fb3256855111b1e78d609c4ce1964a9fdb47a'}, 'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/commits/ac6d42854434acfafe92b60fdf2ed0b038de2070', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None}}

# %%
com
# Out:
# {'commit': {'author': {'name': 'daniloxxv',
#    'email': 'danilosoares@gmail.com',
#    'date': '2019-06-25T17:26:30Z'},
#   'committer': {'name': 'daniloxxv',
#    'email': 'danilosoares@gmail.com',
#    'date': '2019-06-25T17:26:30Z'},
#   'message': 'Uploading module 1 labs',
#   'tree': {'sha': '630fb3256855111b1e78d609c4ce1964a9fdb47a',
#    'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/trees/630fb3256855111b1e78d609c4ce1964a9fdb47a'},
#   'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/commits/ac6d42854434acfafe92b60fdf2ed0b038de2070',
#   'comment_count': 0,
#   'verification': {'verified': False,
#    'reason': 'unsigned',
#    'signature': None,
#    'payload': None}}}

# %% [markdown]
# Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.

# %%
#hacer un ciclo para extraer los archivos de los folders
#jason = []
#for i in range(1):
url=f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
#url=f'https://raw.github.com/repos/ironhack-datalabs/scavenger'
#url:f'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt'
page=requests.get(url, auth=(username,token))
contents_json = page.json()
#https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees{/sha}
df =pd.DataFrame(contents_json)

# %%
df
# Out:
#           name        path                                       sha  size  \
# 0   .gitignore  .gitignore  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf    10
# 1        15024       15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2        15534       15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3        17020       17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4        30351       30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
# 5        40303       40303  30193d9cf62b07bcbb6366513ff03596861f2d29     0
# 6        44639       44639  22fc3d5c2db80822c351edb2248f3491c8ebda86     0
# 7        45525       45525  6a4a88cd9084110c8646c3cfd84dfe96b300a4a7     0
# 8        47222       47222  c7001604cdadc2fe7b82e0f6996690718cac6941     0
# 9        47830       47830  f84882ad7560fd2b8c6a0867bc707ce9009ef288     0
# 10       49418       49418  46bc658c09589d9023246b00e848ce97d30d4989     0
# ...

# %%
cont_json = []
for i in contents_json:
    for key,value in i.items():
        if key == 'url':
            cont_json.append(value)
            #cont_json[key] = value

# %%
len(cont_json)
# Out:
# 26

# %%
#para hacer el super json
s_jason = []

for i in cont_json[1:]:
    #url=f'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/forks?page={i}'
    page=requests.get(i)
    page1 = page.json()
    s_jason.append(page1)

# %%
print(s_jason) #hasta aqui mi practica esta bien
# Out:
# [[{'name': '.0006.scavengerhunt', 'path': '15024/.0006.scavengerhunt', 'sha': '1c9064284a24b3486015eafdb391b141c27ada2b', 'size': 3, 'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt', 'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b', 'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master', 'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b', 'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}}, {'name': '40', 'path': '15024/40', 'sha': 'e69de29bb2d1d643
# ...

# %%
#son de contets 
#lista de urls de folders
y esos me trajeron los json de cada uno
size que 0 si tiene algo
url que dice download
imprimir url libriry


hacer una lista de listas del
create a general list of how many codes there are .000x.scravengers

# %%
#url= 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/forks'
#respuesta= requests.get(url, auth=(username,token))
#respuesta = respuesta.json()



############################
#url= 'https://api.github.com/repos/Katiahsotelo/lab-api-scavenger-game/forks'
#!curl -u Katiahsotelo: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 https://api.github.com/user/Katiahsotelo > output.json
#respuesta = requests.get(url,headers= {'Authorization': 'token {}'.format(oauth_token)})
#respuesta = requests.get(url, auth=('u,'tosername'ken'))
#respuesta= requests.get(url, auth=(username,token))
#respuesta = respuesta.json()
#url = 'https://github.com/trending/developers'
#url='https://github.com/Data-FT-MX/lab-api-scavenger-game/forks'
#page = requests.get(url).content
#page

# %%
sorted(new_list, key=lambda x: x[-19:]

# %%
text=[] 
for i in final_urls:
    URL=i
    GOLDENEGG=requests.get(URL)
    text.append(GOLDENEGG.text.strip())
text
